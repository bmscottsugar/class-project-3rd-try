# %%
import pandas as pd
# Autism study data
import matplotlib.pyplot as plt

import numpy as np

autism_prevalence_studies = pd.read_csv (r"C:\Users\chiro\Desktop\Local Repo 2022 Class Project USE THIS REPO\Class project Assets\autism_prevalence_studies (1).csv")
#Increasing size of data displayed to see all data

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

Population_by_country = pd.read_csv (r"C:\Users\chiro\Desktop\Local Repo 2022 Class Project USE THIS REPO\Class project Assets\population_by_country_2020.csv")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
autism_prevalence_studies
# Out:
#                                                 Author                                              Title  Year Published                Country                                            Area(s)         Age Range       Study Years                         Case Identification Method                                     Case Criterion  Sample Size  Number of Cases  ASD Prevalence Estimate per 1,000 Confidence Interval (CI)  Male:Female Sex Ratio  Non-Hispanic White:Hispanic Prevalence Ratio  White:Black Prevalence Ratio                       Diagnosis Age Range (months)  Diagnosis Mean Age (months)                      Diagnosis Median Age (months)  IQ Score <70 (%)  Adaptive Score <70 (%)  Non-Verbal or Minimally Verbal (%)   Percentage of Individual Co-occurring Conditions                              Autism Types Included                                Link to Publication                              CDC Calculated Values
# ...

# %%
type(autism_prevalence_studies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(autism_prevalence_studies)
# Out:
# 200

# %%
sample_size = autism_prevalence_studies['Sample Size']
type(sample_size)
# Out:
# pandas.core.series.Series

# %%
Prevalence = autism_prevalence_studies['ASD Prevalence Estimate per 1,000']

# %%
type('Prevalence')
# Out:
# str

# %%
plt.figure(figsize = (12,6)) 
plt.scatter(Prevalence, sample_size)
plt.xlabel('Sample Size')#x and y label is character string and must have Quotations
plt.ylabel('Prevalence')
plt.title('Plot of Prevalence vs. sample_size')
plt.show()

# %%
plt.figure(figsize = (12, 6)) 
plt.bar(['Prevalence'],['sample_size'])
plt.xlabel('Sample Size')#x and y label is character string and must have Quotations
plt.ylabel('Prevalence')
plt.title('Plot of Prevalence vs. sample_size')
plt.show()

# %%
Population_by_country
# Out:
#       Country (or dependency)  Population (2020) Yearly Change  Net Change  Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop % World Share
# 0                       China         1440297825        0.39 %     5540090              153          9388211       -348399.0        1.7       38        61 %     18.47 %
# 1                       India         1382345085        0.99 %    13586631              464          2973190       -532687.0        2.2       28        35 %     17.70 %
# 2               United States          331341050        0.59 %     1937734               36          9147420        954806.0        1.8       38        83 %      4.25 %
# 3                   Indonesia          274021604        1.07 %     2898047              151          1811570        -98955.0        2.3       30        56 %      3.51 %
# ...

# %%
Autism_by_Country =  pd.read_csv (r"C:\Users\chiro\Desktop\Local Repo 2022 Class Project USE THIS REPO\Class project Assets\Autism by Country 2022.csv")

# %%
Autism_by_Country
# Out:
#                               country  prevalencePer10K
# 0                               Qatar             151.2
# 1                United Arab Emirates             112.4
# 2                                Oman             107.2
# 3                             Bahrain             103.3
# 4                        Saudi Arabia             100.7
# 5                              Kuwait              97.7
# 6                              Jordan              92.1
# 7                               Syria              91.9
# 8                         Afghanistan              91.2
# 9                           Palestine              91.0
# 10                             Sweden              90.8
# 11                              Libya              90.6
# 12                              Yemen              90.4
# 13                               Iran              90.3
# 14                              Sudan              90.1
# 15                             Mexico              89.9
# ...

# %%
Prevalence_Rate = Autism_by_Country['prevalencePer10K']

# %%
Population_by_country
# Out:
#       Country (or dependency)  Population (2020) Yearly Change  Net Change  Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop % World Share
# 0                       China         1440297825        0.39 %     5540090              153          9388211       -348399.0        1.7       38        61 %     18.47 %
# 1                       India         1382345085        0.99 %    13586631              464          2973190       -532687.0        2.2       28        35 %     17.70 %
# 2               United States          331341050        0.59 %     1937734               36          9147420        954806.0        1.8       38        83 %      4.25 %
# 3                   Indonesia          274021604        1.07 %     2898047              151          1811570        -98955.0        2.3       30        56 %      3.51 %
# ...

# %%
Country_Population = Population_by_country['Population(2020)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population(2020)'
#
# The above exception was the direct cause of the following exception:
#
# ...
